# %%
import pandas as pd
import numpy as np
df=pd.read_csv("owid-covid-data.csv")

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243636 entries, 0 to 243635
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    243636 non-null  object
#  1   continent                                   229936 non-null  object
#  2   location                                    243636 non-null  object
#  3   date                                        243636 non-null  object
#  4   total_cases                                 229626 non-null  float64
#  5   new_cases                                   229247 non-null  float64
#  6   new_cases_smoothed                          228048 non-null  float64
#  7   total_deaths                                210205 non-null  float64
#  8   new_deaths                                  210100 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   13700
# location                                        0
# date                                            0
# total_cases                                 14010
#                                             ...
# population                                   1046
# excess_mortality_cumulative_absolute       235549
# excess_mortality_cumulative                235549
# excess_mortality                           235520
# excess_mortality_cumulative_per_million    235549
# Length: 67, dtype: int64

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   13700
# location                                        0
# date                                            0
# total_cases                                 14010
#                                             ...
# population                                   1046
# excess_mortality_cumulative_absolute       235549
# excess_mortality_cumulative                235549
# excess_mortality                           235520
# excess_mortality_cumulative_per_million    235549
# Length: 67, dtype: int64

# %%
mean=df[["excess_mortality_cumulative_absolute","excess_mortality_cumulative","excess_mortality","excess_mortality_cumulative_per_million","total_cases"]].mean

# %%
df.fillna(df.mean(numeric_only=True).round(1), inplace=True)

# %%
df.isnull().sum()
# Out:
# iso_code                                       0
# continent                                  13700
# location                                       0
# date                                           0
# total_cases                                    0
#                                            ...
# population                                     0
# excess_mortality_cumulative_absolute           0
# excess_mortality_cumulative                    0
# excess_mortality                               0
# excess_mortality_cumulative_per_million        0
# Length: 67, dtype: int64

# %%
df.shape
# Out:
# (243636, 67)

# %%
df1= df.dropna()

# %%
df1.shape
# Out:
# (106788, 67)

# %%
df1.to_csv("covid19.csv", index=False)
